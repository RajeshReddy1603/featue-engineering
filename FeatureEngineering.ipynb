# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
d={
    "company":["google","twitter","google","linkedin"],
    "role":["datascientist","salesmanager","hr","hr"]
}
df=pd.DataFrame(d)
obj=LabelEncoder()
df["company_n"]=obj.fit_transform(df["company"])
df["role_n"]=obj.fit_transform(df["role"])
print(df)
# Out:
#     company           role  company_n  role_n
# 0    google  datascientist          0       0
# 1   twitter   salesmanager          2       2
# 2    google             hr          0       1
# 3  linkedin             hr          1       1

# %%
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

a={
    "company":["google","twitter","google","linkedin"],
    "role":["datascientist","salesmanager","hr","hr"]
}
df=pd.DataFrame(a)
a=LabelEncoder()
df["company_n"]=a.fit_transform(df["company"])
df["role_n"]=a.fit_transform(df["role"])
df
# Out:
#     company           role  company_n  role_n
# 0    google  datascientist          0       0
# 1   twitter   salesmanager          2       2
# 2    google             hr          0       1
# 3  linkedin             hr          1       1

# %%
import sklearn.preprocessing as sp
print(dir(sp))
# Out:
# ['Binarizer', 'FunctionTransformer', 'KBinsDiscretizer', 'KernelCenterer', 'LabelBinarizer', 'LabelEncoder', 'MaxAbsScaler', 'MinMaxScaler', 'MultiLabelBinarizer', 'Normalizer', 'OneHotEncoder', 'OrdinalEncoder', 'PolynomialFeatures', 'PowerTransformer', 'QuantileTransformer', 'RobustScaler', 'SplineTransformer', 'StandardScaler', 'TargetEncoder', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_csr_polynomial_expansion', '_data', '_discretization', '_encoders', '_function_transformer', '_label', '_polynomial', '_target_encoder', '_target_encoder_fast', 'add_dummy_feature', 'binarize', 'label_binarize', 'maxabs_scale', 'minmax_scale', 'normalize', 'power_transform', 'quantile_transform', 'robust_scale', 'scale']

# %%
import pandas as pd
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
a={
    "company":["google","twitter","google","linkedin"],
    "role":["datascientist","salesmanager","hr","hr"]
}
df=pd.DataFrame(a)
obj=LabelEncoder()
df["company_n"]=obj.fit_transform(df["company"])
df["role_n"]=obj.fit_transform(df["role"])
print(df)
# Out:
#     company           role  company_n  role_n
# 0    google  datascientist          0       0
# 1   twitter   salesmanager          2       2
# 2    google             hr          0       1
# 3  linkedin             hr          1       1

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
a={"company":["google","twitter","google","linkedin"],
    "role":["datascientist","salesmanager","hr","hr"]
  }
df=pd.DataFrame(a)
x=LabelEncoder()
df["company_x"]=x.fit_transform(df["company"])
df["role_x"]=x.fit_transform(df["company"])
df
# Out:
#     company           role  company_x  role_x
# 0    google  datascientist          0       0
# 1   twitter   salesmanager          2       2
# 2    google             hr          0       0
# 3  linkedin             hr          1       1

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
a={
    "names":["rajesh","maddi","today","tomorrow","world"],
     "values":["uk","usa","canada","newzlend","ok"]
}
df=pd.DataFrame(a)
x=LabelEncoder()
df["names_n"]=x.fit_transform(df["names"])
df["values_n"]=x.fit_transform(df["values"])
print(df)
# Out:
#       names    values  names_n  values_n
# 0    rajesh        uk        1         3
# 1     maddi       usa        0         4
# 2     today    canada        2         0
# 3  tomorrow  newzlend        3         1
# 4     world        ok        4         2

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[23,45,56,78,99,100],
     "y":[56,67,78,88,99,100]
}
df=pd.DataFrame(a)
obj=MinMaxScaler(feature_range=(0,1))
result=obj.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.28571429, 0.25      ],
#        [0.42857143, 0.5       ],
#        [0.71428571, 0.72727273],
#        [0.98701299, 0.97727273],
#        [1.        , 1.        ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["vija","hyd","kerala","tamil","maha"],
     "values":["today","tomorrow","ok","tiruvuru","now"]
}
df=pd.DataFrame(a)
x=LabelEncoder()
df["names_n"]=x.fit_transform(df["names"])
df["values_n"]=x.fit_transform(df["values"])
print(df)
# Out:
#     names    values  names_n  values_n
# 0    vija     today        4         3
# 1     hyd  tomorrow        0         4
# 2  kerala        ok        1         1
# 3   tamil  tiruvuru        3         2
# 4    maha       now        2         0

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60],
     "y":[100,200,300,400,500,600]
}
df=pd.DataFrame(a)
x=MinMaxScaler(feature_range=(0,1))
result=x.fit_transform(df[["x","y"]])
result
# Out:
# array([[0. , 0. ],
#        [0.2, 0.2],
#        [0.4, 0.4],
#        [0.6, 0.6],
#        [0.8, 0.8],
#        [1. , 1. ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["today","tomorrow","hello","ok","chintu"],
     "values":["rajesh","maddi","today","tomorrow","hyderbad"]
}
df=pd.DataFrame(a)
x=LabelEncoder()
df["names_x"]=x.fit_transform(df["names"])
df["values_x"]=x.fit_transform(df["values"])
df
# Out:
#       names    values  names_x  values_x
# 0     today    rajesh        3         2
# 1  tomorrow     maddi        4         1
# 2     hello     today        1         3
# 3        ok  tomorrow        2         4
# 4    chintu  hyderbad        0         0

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70],
     "y":[120,130,140,150,160,170,180]
}
df=pd.DataFrame(a)
x=MinMaxScaler(feature_range=(0,1))
result=x.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.16666667, 0.16666667],
#        [0.33333333, 0.33333333],
#        [0.5       , 0.5       ],
#        [0.66666667, 0.66666667],
#        [0.83333333, 0.83333333],
#        [1.        , 1.        ]])

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70,80],
     "y":[100,200,300,400,500,600,700,800]
}
df=pd.DataFrame(a)
x=MinMaxScaler(feature_range=(0,1))
result=x.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.14285714, 0.14285714],
#        [0.28571429, 0.28571429],
#        [0.42857143, 0.42857143],
#        [0.57142857, 0.57142857],
#        [0.71428571, 0.71428571],
#        [0.85714286, 0.85714286],
#        [1.        , 1.        ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["rajesh","maddi","today","tomorrow","aha"],
     "values":["amazon","netflix","aha","hello","lidil"]
}
df=pd.DataFrame(a)
x=LabelEncoder()
df["names_n"]=x.fit_transform(df["names"])
df["values_n"]=x.fit_transform(df["values"])
df
# Out:
#       names   values  names_n  values_n
# 0    rajesh   amazon        2         1
# 1     maddi  netflix        1         4
# 2     today      aha        3         0
# 3  tomorrow    hello        4         2
# 4       aha    lidil        0         3

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70],
    "y":[100,200,300,400,500,600,700]
}
df=pd.DataFrame(a)
x=MinMaxScaler(feature_range=(0,1))
result=x.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.16666667, 0.16666667],
#        [0.33333333, 0.33333333],
#        [0.5       , 0.5       ],
#        [0.66666667, 0.66666667],
#        [0.83333333, 0.83333333],
#        [1.        , 1.        ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["amazon","netflix","aha","lidil","asda"],
     "values":["today","tomorrow","helo","world","rajesh"]
}
df=pd.DataFrame(a)
obj=LabelEncoder()
df["names_n"]=obj.fit_transform(df["names"])
df["values_n"]=obj.fit_transform(df["values"])
df
# Out:
#      names    values  names_n  values_n
# 0   amazon     today        1         2
# 1  netflix  tomorrow        4         3
# 2      aha      helo        0         0
# 3    lidil     world        3         4
# 4     asda    rajesh        2         1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70,80],
     "y":[100,200,300,400,500,600,700,800]
}
df=pd.DataFrame(a)
obj=MinMaxScaler(feature_range=(0,1))
result=obj.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.14285714, 0.14285714],
#        [0.28571429, 0.28571429],
#        [0.42857143, 0.42857143],
#        [0.57142857, 0.57142857],
#        [0.71428571, 0.71428571],
#        [0.85714286, 0.85714286],
#        [1.        , 1.        ]])

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["amazon","netflix","aha","asda","lidil"],
     "values":["rajesh","maddi","today","tomorrow","ok"]
}
df=pd.DataFrame(a)
obj=LabelEncoder()
df["names_n"]=obj.fit_transform(df["names"])
df["values_n"]=obj.fit_transform(df["values"])

df
# Out:
#      names    values  names_n  values_n
# 0   amazon    rajesh        1         2
# 1  netflix     maddi        4         0
# 2      aha     today        0         3
# 3     asda  tomorrow        2         4
# 4    lidil        ok        3         1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70],
     "y":[100,200,300,400,500,600,700]
}
df=pd.DataFrame(a)
obj=MinMaxScaler(feature_range=(0,1))
result=obj.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.16666667, 0.16666667],
#        [0.33333333, 0.33333333],
#        [0.5       , 0.5       ],
#        [0.66666667, 0.66666667],
#        [0.83333333, 0.83333333],
#        [1.        , 1.        ]])

# %%
import os
import pandas as pd
a="./daniel"
all_files=os.listdir(a)
all_files
# Out:
# ['apr_sales.csv',
#  'aug_sales.csv',
#  'dec_sales.csv',
#  'feb_sales.csv',
#  'fun.jpg',
#  'jan_sales.csv',
#  'jul_sales.csv',
#  'jun_sales.csv',
#  'mar_sales.csv',
#  'may_sales.csv',
#  'nov_sales.csv',
#  'oct_sales.csv',
#  'progress.txt',
#  'sep_sales.csv',
#  'status.xlsx']

# %%
import os
import pandas as pd
a="./daniel"
all_files=os.listdir(a)
csv_files=filter(lambda a : a.endswith(".csv"),all_files)
list(csv_files)
# Out:
# ['apr_sales.csv',
#  'aug_sales.csv',
#  'dec_sales.csv',
#  'feb_sales.csv',
#  'jan_sales.csv',
#  'jul_sales.csv',
#  'jun_sales.csv',
#  'mar_sales.csv',
#  'may_sales.csv',
#  'nov_sales.csv',
#  'oct_sales.csv',
#  'sep_sales.csv']

# %%
import os
import glob
import pandas as pd
a="./daniel"
all_files=os.path.join(a,"*csv")
files=glob.glob(all_files)
df=[pd.read_csv(file) for file in files]
result=pd.concat(df,ignore_index=True)
result
# Out:
#      Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0        1320          Venu           23      LG ThinQ Refrigerator
# 1        1321  Jaya Chandra           21  Bose SoundSport Headphones
# 2        1322   Mallikarjun           13    Apple Airpods Headphones
# 3        1323        Siddhu           18      Samsung Galaxy S9 Plus
# 4        1324        Daniel            6                    iPhone 8
# ..        ...           ...          ...                         ...
# 103      1819        Daniel            6          LG Washing Machine
# 104      1820       Neelima           19                20in Monitor
# 105      1821       Karteek            4                20in Monitor
# 106      1822  Jaya Chandra           21      LG ThinQ Refrigerator
# 107      1823    Chaithanya           14            27in FHD Monitor
#
#      Product_Cost             Date
# 0           55000   4/11/2019 9:00
# 1           63000  4/13/2019 10:00
# ...

# %%
import pandas as pd
df=pd.read_csv("sales4.csv")
df
# Out:
#         Order_Id Customer_Name  Customer_Id                Product_Name  \
# 0           1023         Venki           15            27in FHD Monitor
# 1           1024    Chaithanya           14                   iPhone 11
# 2           1025        Shahid           20  Bose SoundSport Headphones
# 3           1026         Veeru            3        Apple iPad 10.2-inch
# 4           1027          Venu           23                Google Phone
# ...          ...           ...          ...                         ...
# 299995    301018       Karteek            4        Apple iPad 10.2-inch
# 299996    301019         Veeru            3          Macbook Pro Laptop
# 299997    301020        Harsha            5          LG Washing Machine
# 299998    301021    Nireekshan            1                   LG Mobile
# 299999    301022       Pradhan           17      34in Ultrawide Monitor
#
#         Product_Cost
# 0              59000
# 1              69000
# 2              65999
# ...

# %%
cond1=df["Customer_Name"]=="Chaithanya"
cond2=df["Product_Name"]=="iPhone 11"
df1=df.loc[cond1&cond2]
df1
# Out:
#         Order_Id Customer_Name  Customer_Id Product_Name  Product_Cost
# 1           1024    Chaithanya           14    iPhone 11         69000
# 836         1859    Chaithanya           14    iPhone 11         75000
# 2402        3425    Chaithanya           14    iPhone 11         55000
# 2440        3463    Chaithanya           14    iPhone 11         65999
# 2717        3740    Chaithanya           14    iPhone 11         59000
# ...          ...           ...          ...          ...           ...
# 297175    298198    Chaithanya           14    iPhone 11         65999
# 298521    299544    Chaithanya           14    iPhone 11         75999
# 298560    299583    Chaithanya           14    iPhone 11         50000
# 299461    300484    Chaithanya           14    iPhone 11         60000
# 299489    300512    Chaithanya           14    iPhone 11         75000
#
# [548 rows x 5 columns]

# %%
cond1=df["Customer_Name"]=="Karteek"
cond2=df["Product_Name"]=="27in FHD Monitor"
df[cond1&cond2]
# Out:
#         Order_Id Customer_Name  Customer_Id      Product_Name  Product_Cost
# 69          1092       Karteek            4  27in FHD Monitor         55999
# 667         1690       Karteek            4  27in FHD Monitor         61000
# 891         1914       Karteek            4  27in FHD Monitor         65000
# 1141        2164       Karteek            4  27in FHD Monitor         75000
# 2185        3208       Karteek            4  27in FHD Monitor         65000
# ...          ...           ...          ...               ...           ...
# 297273    298296       Karteek            4  27in FHD Monitor         59000
# 297711    298734       Karteek            4  27in FHD Monitor         50000
# 297835    298858       Karteek            4  27in FHD Monitor         50000
# 299034    300057       Karteek            4  27in FHD Monitor         69000
# 299039    300062       Karteek            4  27in FHD Monitor         61000
#
# [599 rows x 5 columns]

# %%
a=["Apple iPad 10.2-inch","LG Washing Machine","LG Mobile"]
b=df["Product_Name"].isin(a)
df1=df[b]
df1
# Out:
#         Order_Id Customer_Name  Customer_Id          Product_Name  \
# 3           1026         Veeru            3  Apple iPad 10.2-inch
# 9           1032       Neelima           19    LG Washing Machine
# 24          1047         Shafi           25    LG Washing Machine
# 27          1050         Veeru            3             LG Mobile
# 28          1051       Lavanya           16    LG Washing Machine
# ...          ...           ...          ...                   ...
# 299971    300994         Vinay           10             LG Mobile
# 299976    300999         Veeru            3             LG Mobile
# 299995    301018       Karteek            4  Apple iPad 10.2-inch
# 299997    301020        Harsha            5    LG Washing Machine
# 299998    301021    Nireekshan            1             LG Mobile
#
#         Product_Cost
# 3              63999
# 9              63000
# 24             63999
# 27             51999
# 28             75000
# ...              ...
# ...

# %%
import pandas as pd
df=pd.read_csv("sales1.csv")
df
# Out:
#      Order ID Customer Name                 Product  Quantity
# 0      166837         Veeru  34in Ultrawide Monitor         2
# 1      166838         Tarun             Samsung m10         3
# 2      166839         Kedar            20in Monitor         1
# 3      166840       Lavanya               iPhone 11         3
# 4      166841          Venu      Macbook Pro Laptop         2
# ..        ...           ...                     ...       ...
# 595    167403        Balaji      Macbook Pro Laptop         1
# 596    167404       Lavanya         ThinkPad Laptop         1
# 597    167405          Venu           Flatscreen TV         1
# 598    167406        Siddhu             Samsung m20         2
# 599    167407         Tarun      LG Washing Machine         1
#
# [600 rows x 4 columns]

# %%
df.set_index("Product",inplace=True)

# %%
df
# Out:
#                         Order ID Customer Name  Quantity
# Product
# 34in Ultrawide Monitor    166837         Veeru         2
# Samsung m10               166838         Tarun         3
# 20in Monitor              166839         Kedar         1
# iPhone 11                 166840       Lavanya         3
# Macbook Pro Laptop        166841          Venu         2
# ...                          ...           ...       ...
# Macbook Pro Laptop        167403        Balaji         1
# ThinkPad Laptop           167404       Lavanya         1
# Flatscreen TV             167405          Venu         1
# Samsung m20               167406        Siddhu         2
# LG Washing Machine        167407         Tarun         1
#
# [600 rows x 3 columns]

# %%
rows=["20in Monitor"]
df1=df.loc[rows]
df1
# Out:
#               Order ID Customer Name  Quantity
# Product
# 20in Monitor    166839         Kedar         1
# 20in Monitor    166942         Tarun         1
# 20in Monitor    166951         Kedar         1
# 20in Monitor    166953         Tarun         1
# 20in Monitor    166985         Sagar         1
# 20in Monitor    167008        Shahid         1
# 20in Monitor    167032    Chaithanya         2
# 20in Monitor    167070       Pradhan         1
# 20in Monitor    167077        Partha         2
# 20in Monitor    167090    Nireekshan         1
# 20in Monitor    167096         Kedar         3
# 20in Monitor    167112         Sagar         1
# 20in Monitor    167138         Vinay         1
# 20in Monitor    167153     Madhurima         1
# 20in Monitor    167154       Sumanth         1
# 20in Monitor    167162         Veeru         1
# 20in Monitor    167206         Kedar         1
# 20in Monitor    167327       Neelima         3
# 20in Monitor    167408         Veeru         3

# %%
rows=["iPhone 11","Macbook Pro Laptop"]
cols=["Customer Name","Quantity"]
df1=df.loc[rows,cols]
df1
# Out:
#                    Customer Name  Quantity
# Product
# iPhone 11                Lavanya         3
# iPhone 11                 Siddhu         1
# iPhone 11             Chaithanya         1
# iPhone 11                Neelima         1
# iPhone 11                Lavanya         1
# iPhone 11             Chaithanya         2
# iPhone 11                Karteek         1
# iPhone 11             Chaithanya         3
# iPhone 11                  Sagar         3
# iPhone 11                Sumanth         1
# iPhone 11                  Sagar         1
# iPhone 11                 Siddhu         1
# iPhone 11                  Tarun         1
# iPhone 11                 Balaji         2
# iPhone 11                  Vijay         2
# iPhone 11                Pradhan         1
# iPhone 11                Pradhan         1
# iPhone 11            Mallikarjun         2
# iPhone 11             Nireekshan         1
# iPhone 11                Karteek         2
# iPhone 11                 Shahid         1
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["amazon","asda","lidil","tesco","coop"],
     "values":["rajesh","maddi","today","tomorrow","ok"]
}
df=pd.DataFrame(a)
obj=LabelEncoder()
df["names_n"]=obj.fit_transform(df["names"])
df["values_n"]=obj.fit_transform(df["values"])
df
# Out:
#     names    values  names_n  values_n
# 0  amazon    rajesh        0         2
# 1    asda     maddi        1         0
# 2   lidil     today        3         3
# 3   tesco  tomorrow        4         4
# 4    coop        ok        2         1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50],
     "y":[100,200,300,400,500]
}
df=pd.DataFrame(a)
obj=MinMaxScaler(feature_range=(0,1))
result=obj.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.  , 0.  ],
#        [0.25, 0.25],
#        [0.5 , 0.5 ],
#        [0.75, 0.75],
#        [1.  , 1.  ]])

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50]
b=[90,91,92,93,94]
plt.scatter(a,b)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
a={
    "names":["amazon","lidil","aha","netflix","asda"],
     "values":["hello","world","today","tomorrow","ok"]
}
df=pd.DataFrame(a)
obj=LabelEncoder()
df["names_n"]=obj.fit_transform(df["names"])
df["values_n"]=obj.fit_transform(df["values"])
df
# Out:
#      names    values  names_n  values_n
# 0   amazon     hello        1         0
# 1    lidil     world        3         4
# 2      aha     today        0         2
# 3  netflix  tomorrow        4         3
# 4     asda        ok        2         1

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
a={
    "x":[10,20,30,40,50,60,70],
     "y":[100,200,300,400,500,600,700]
}
df=pd.DataFrame(a)
obj=MinMaxScaler(feature_range=(0,1))
result=obj.fit_transform(df[["x","y"]])
result
# Out:
# array([[0.        , 0.        ],
#        [0.16666667, 0.16666667],
#        [0.33333333, 0.33333333],
#        [0.5       , 0.5       ],
#        [0.66666667, 0.66666667],
#        [0.83333333, 0.83333333],
#        [1.        , 1.        ]])
